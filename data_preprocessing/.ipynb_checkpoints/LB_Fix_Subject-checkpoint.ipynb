# %%
# Import many dataFrame for the Algorithm Comparison:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from matplotlib.lines import Line2D
from scipy import stats

import glob
import os

# internal imports
import fixation_plots as plots
import math_calc

# %%
counter = 14
tracker_type = "lb"

# %%
for i in range(3,counter):
    df_lb = pd.read_csv('../data/lb_data/fixations_data/p' + str(i) + '_fixations.csv')
    df_lb_trial = pd.read_csv('../data/lb_data/lb_trial_pp/p' + str(i) + '_trial_pp.csv')
    # df_lb_trial = pd.read_csv('../data/lb_data/trial_data/p' + str(i) + '_trials.csv')
    
    
    # format whole data
    df_lb = math_calc.formating_timeseries(df_lb)
    df_lb_trial = math_calc.formating_trials(df_lb_trial)
    # Calculate the offset-fixations
    df_offsetFix = math_calc.calcOffsetFixation(tracker_type,df_lb_trial, df_lb)
    # Caluclate The Euclidan Distance
    df_offsetFix = math_calc.calcEuclideanDistance(df_offsetFix, df_lb_trial)
    # Add to the dataframe column with participant number:
    df_offsetFix = math_calc.addParticipantNumberCol(i, df_offsetFix)

    #Plot distance to target and Dispersion
    plots.distanceToTargetPlot(tracker_type, i, df_lb_trial, df_offsetFix)
    plots.dispersionGridScatter(tracker_type, i, df_lb_trial, df_offsetFix)
    plots.precisionScatterScatter(tracker_type, i, df_lb_trial, df_offsetFix)

    df_offsetFix.to_csv('../data/lb_data/last_fixation_data/' + str(i) + '_lb_fix.csv', index = False)
    df_lb_trial.to_csv('../data/lb_data/lb_trial_pp/p' + str(i) + '_trial_pp.csv', index = False)

# %%
# Out:
#     level_0  Block_Nr_x Block_Name_x  Task_Nr_x Task_Name_x  Trial_Nr_x  \
# 0       654           1      block_1          3  large_grid           1
# 1       673           1      block_1          3  large_grid           3
# 2       683           1      block_1          3  large_grid           4
# 3       693           1      block_1          3  large_grid           5
# 4       744           1      block_1          3  large_grid          10
# 5       754           1      block_1          3  large_grid          11
# 6       772           1      block_1          3  large_grid          13
# 7       782           1      block_1          3  large_grid          14
# 8       792           1      block_1          3  large_grid          15
# 9       802           1      block_1          3  large_grid          16
# 10      811           1      block_1          3  large_grid          17
# 11      820           1      block_1          3  large_grid          18
# 12      830           1      block_1          3  large_grid          19
# 13      839           1      block_1          3  large_grid          20
# 14      867           1      block_1          3  large_grid          23
# 15      877           1      block_1          3  large_grid          24
# 16      903           1      block_1          3  large_grid          27
# 17      931           1      block_1          3  large_grid          30
# 18      940           1      block_1          3  large_grid          31
# 19      949           1      block_1          3  large_grid          32
# 20      978           1      block_1          3  large_grid          35
# 21      995           1      block_1          3  large_grid          37
# 22     1005           1      block_1          3  large_grid          38
# 23     1022           1      block_1          3  large_grid          40
# 24     1032           1      block_1          3  large_grid          41
# 25     1042           1      block_1          3  large_grid          42
# 26     1051           1      block_1          3  large_grid          43
# 27     1060           1      block_1          3  large_grid          44
# 28     1070           1      block_1          3  large_grid          45
# 29     1079           1      block_1          3  large_grid          46
# 30     1106           1      block_1          3  large_grid          49
# 31     1125           1      block_1          3  large_grid          51
# 32     1134           1      block_1          3  large_grid          52
# 33     1168           1      block_1          3  large_grid          55
# 34     1177           1      block_1          3  large_grid          56
#
#     Trial_Id_x  Exp_Subject_Id  Rec_Session_Id_x  Session_Nr  ...  \
# 0           53          387030            433618           1  ...
# 1           27          387030            433618           1  ...
# 2           46          387030            433618           1  ...
# 3           35          387030            433618           1  ...
# 4           51          387030            433618           1  ...
# 5           43          387030            433618           1  ...
# 6           12          387030            433618           1  ...
# 7           11          387030            433618           1  ...
# 8           33          387030            433618           1  ...
# 9           47          387030            433618           1  ...
# 10           1          387030            433618           1  ...
# 11           3          387030            433618           1  ...
# 12          23          387030            433618           1  ...
# 13          19          387030            433618           1  ...
# 14           2          387030            433618           1  ...
# 15          32          387030            433618           1  ...
# 16          14          387030            433618           1  ...
# 17          38          387030            433618           1  ...
# 18          30          387030            433618           1  ...
# 19          13          387030            433618           1  ...
# 20           9          387030            433618           1  ...
# 21          54          387030            433618           1  ...
# 22          25          387030            433618           1  ...
# 23          18          387030            433618           1  ...
# 24          41          387030            433618           1  ...
# 25          21          387030            433618           1  ...
# 26          55          387030            433618           1  ...
# 27          56          387030            433618           1  ...
# 28           5          387030            433618           1  ...
# 29          24          387030            433618           1  ...
# 30          15          387030            433618           1  ...
# 31          37          387030            433618           1  ...
# 32          22          387030            433618           1  ...
# 33          48          387030            433618           1  ...
# 34          42          387030            433618           1  ...
#
#       StartFrame  target_visibility_afterTime  targetX  targetY  \
# 0   1.646992e+12                       2189.0      320      600
# 1   1.646992e+12                       2416.0     1120      800
# 2   1.646992e+12                       2398.0      520      100
# 3   1.646992e+12                       2102.0     1320      800
# 4   1.646992e+12                       2461.0     1120      600
# 5   1.646992e+12                       2161.0     1320      700
# 6   1.646992e+12                       2158.0     1120      100
# 7   1.646992e+12                       2371.0     1120      700
# 8   1.646992e+12                       2187.0      120      800
# 9   1.646992e+12                       2110.0      120      400
# 10  1.646992e+12                       2350.0      920      500
# 11  1.646992e+12                       2117.0      720      400
# 12  1.646992e+12                       2443.0      920      300
# 13  1.646992e+12                       2481.0      920      600
# 14  1.646992e+12                       2069.0      720      300
# 15  1.646992e+12                       2445.0     1120      200
# 16  1.646992e+12                       2048.0      120      200
# 17  1.646992e+12                       2066.0      720      700
# 18  1.646992e+12                       2203.0      520      500
# 19  1.646992e+12                       2070.0      720      600
# 20  1.646992e+12                       2125.0      920      700
# 21  1.646992e+12                       2076.0     1320      500
# 22  1.646992e+12                       2153.0      120      300
# 23  1.646992e+12                       2467.0      720      500
# 24  1.646992e+12                       2320.0      520      700
# 25  1.646992e+12                       2154.0      320      100
# 26  1.646992e+12                       2302.0      520      800
# 27  1.646992e+12                       2217.0     1120      500
# 28  1.646992e+12                       2217.0      120      500
# 29  1.646992e+12                       2200.0      320      200
# 30  1.646992e+12                       2206.0      320      700
# 31  1.646992e+12                       2433.0      120      700
# 32  1.646992e+12                       2236.0      920      200
# 33  1.646992e+12                       2452.0      320      400
# 34  1.646992e+12                       2404.0      920      100
#
#     time_offset_beep  time_sound_beep  trial_error  videoRecordTime  \
# 0                NaN              NaN    90.565346              NaN
# 1                NaN              NaN    90.565346              NaN
# 2                NaN              NaN    90.565346              NaN
# 3                NaN              NaN    90.565346              NaN
# 4                NaN              NaN    92.545998              NaN
# 5                NaN              NaN    92.545998              NaN
# 6                NaN              NaN    62.707523              NaN
# 7                NaN              NaN    62.707523              NaN
# 8                NaN              NaN    62.707523              NaN
# 9                NaN              NaN    62.707523              NaN
# 10               NaN              NaN    62.707523              NaN
# 11               NaN              NaN    62.707523              NaN
# 12               NaN              NaN    62.137863              NaN
# 13               NaN              NaN    62.137863              NaN
# 14               NaN              NaN    62.137863              NaN
# 15               NaN              NaN    62.137863              NaN
# 16               NaN              NaN    42.691574              NaN
# 17               NaN              NaN    42.691574              NaN
# 18               NaN              NaN    86.505814              NaN
# 19               NaN              NaN    86.505814              NaN
# 20               NaN              NaN    86.505814              NaN
# 21               NaN              NaN    56.813538              NaN
# 22               NaN              NaN    56.813538              NaN
# 23               NaN              NaN    56.813538              NaN
# 24               NaN              NaN    56.813538              NaN
# 25               NaN              NaN    56.813538              NaN
# 26               NaN              NaN    86.947014              NaN
# 27               NaN              NaN    86.947014              NaN
# 28               NaN              NaN    86.947014              NaN
# 29               NaN              NaN    86.947014              NaN
# 30               NaN              NaN   138.268173              NaN
# 31               NaN              NaN   138.268173              NaN
# 32               NaN              NaN   138.268173              NaN
# 33               NaN              NaN    70.299835              NaN
# 34               NaN              NaN    70.299835              NaN
#
#     reactionTimeCalc  target_offset
# 0              475.0  1646991559701
# 1              346.0  1646991566538
# 2              295.0  1646991570027
# 3              327.0  1646991573183
# 4              265.0  1646991616845
# 5              375.0  1646991620025
# 6              403.0  1646991675852
# 7              375.0  1646991679377
# 8              435.0  1646991682684
# 9              346.0  1646991685992
# 10             320.0  1646991689427
# 11             342.0  1646991692617
# 12             309.0  1646991754450
# 13             332.0  1646991757985
# 14             393.0  1646991768103
# 15             146.0  1646991771694
# 16             317.0  1646991823438
# 17             294.0  1646991833339
# 18             142.0  1646991851071
# 19             319.0  1646991854027
# 20             280.0  1646991863961
# 21             406.0  1646991884565
# 22             297.0  1646991887872
# 23             308.0  1646991894801
# 24             294.0  1646991898173
# 25             318.0  1646991901380
# 26             347.0  1646991960641
# 27             327.0  1646991963943
# 28             149.0  1646991967232
# 29             299.0  1646991970321
# 30             328.0  1646992009131
# 31             108.0  1646992015720
# 32             356.0  1646992018809
# 33             271.0  1646992046092
# 34             284.0  1646992049515
#
# [35 rows x 60 columns]
