# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
pd.set_option('display.max_columns', None)

# %%
lb = pd.read_csv('../data/lb_data/1/timeseries_data/timeseries_data.csv')
el = pd.read_csv('../data/el_data/p1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-8a88706939ae> in <module>
# ----> 1 lb = pd.read_csv('../data/lb_data/1/timeseries_data/timeseries_data.csv')
#       2 el = pd.read_csv('../data/el_data/p1.csv')
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/lb_data/1/timeseries_data/timeseries_data.csv'

# %%
# Formating and Name Changing of the Labvanced and Eyelink Data.
el.Time = el.Time.apply(lambda x: int('%.0f' % (x * 1000)))
lb_fix = lb[lb['variable_name']=="fixations"]
lb = lb[lb['Task_Name'] == "large_grid"]
lb = lb[lb['variable_name'] == "XYTC"]
# df.rename(columns={"A": "a", "B": "c"})
lb = lb.rename(columns={"values":"X_lb","Unnamed: 12":"Y_lb","Unnamed: 13":"time_lb","Unnamed: 14":'c'})
lb['difference'] = lb['time_lb'] - lb['times']
# print(lb.mean())
# lb['time_lb'] = lb['time_lb'] - 1959600
# Format time column
lb['times'] = lb['times'].fillna(0)
lb = lb[(lb[['times']] != 0).all(axis=1)]

lb['time_lb'] = lb['time_lb'].fillna(0)
lb = lb[(lb[['time_lb']] != 0).all(axis=1)]
lb.time_lb = lb.time_lb.apply(lambda x: int('%.0f' % x))

# # Sort data towards the time column
# lb.sort_values('time_lb', inplace=True)

# # Fill all nan values with 0
lb[['X_lb','Y_lb']] = lb[['X_lb','Y_lb']].fillna(0)

# lb[['X_lb','Y_lb']] = lb[['X_lb','Y_lb']] + 200
# # Convert the coordinates points from floats to intergers
lb[['X_lb','Y_lb']] = lb[['X_lb','Y_lb']].apply(np.int64)
lb = lb[(lb[['X_lb']] != 0).all(axis=1)]

# %%
lb['tsDiff'] = lb['time_lb'].diff()
print('The median difference is')
print(lb.tsDiff.median())
# Out:
# The median difference is
# 33.0

# %%
correction = input()
lb['time_lb'] = lb['time_lb'] - int(correction)
# Out:
# 100

# %%
# EYE LINK DATA rename the eyelink columns
el = el.rename(columns={'X':'X_el','Y':'Y_el','Time':'t'})
el['time_el'] = el['t']

# %%
#If so delete this row
el = el[(el[['X_el','Y_el','time_el']] != 0).all(axis=1)]
el.dropna(inplace=True)
#Check once agian
print('show missing data in eyelink dataset')
(el == 0).sum(axis=0)
# Out:
# show missing data in eyelink dataset
# X_el       0
# Y_el       0
# t          0
# time_el    0
# dtype: int64

# %%
# set the index column
el = el.set_index('t')
df_xy = lb.set_index('time_lb')
# df_xy.info()

# %% [markdown]
# ## Interpolation of the eyelink data

# %%
# Interpolate data
df_temp = pd.concat([el, df_xy.index.to_frame()]).sort_index().interpolate()
df_temp = df_temp[~df_temp.index.duplicated(keep='first')]
df_xy = df_xy.merge(df_temp, left_index=True, right_index=True, how='left')
# df_xy

# %%
#Check if you have any 0 or Nan values it might mess up the data and the calculation 
(df_xy.isnull()).sum(axis=0)
# Out:
# Block_Name        0
# Block_Nr          0
# exp_subject_id    0
# rec_session_id    0
# session_nr        0
# Task_Name         0
# Task_Nr           0
# times             0
# Trial_Id          0
# Trial_Nr          0
# variable_name     0
# X_lb              0
# Y_lb              0
# c                 0
# difference        0
# tsDiff            1
# X_el              0
# Y_el              0
# time_el           0
# time_lb           0
# dtype: int64

# %%
(df_xy == 0).sum(axis=0)
# Out:
# Block_Name        0
# Block_Nr          0
# exp_subject_id    0
# rec_session_id    0
# session_nr        0
# Task_Name         0
# Task_Nr           0
# times             0
# Trial_Id          0
# Trial_Nr          0
# variable_name     0
# X_lb              0
# Y_lb              0
# c                 9
# difference        0
# tsDiff            0
# X_el              0
# Y_el              0
# time_el           0
# time_lb           0
# dtype: int64

# %%
#If so delete this row
df_xy = df_xy[(df_xy[['X_el','Y_el','time_lb']] != 0).all(axis=1)]
#Check once agian
(df_xy == 0).sum(axis=0)
# Out:
# Block_Name        0
# Block_Nr          0
# exp_subject_id    0
# rec_session_id    0
# session_nr        0
# Task_Name         0
# Task_Nr           0
# times             0
# Trial_Id          0
# Trial_Nr          0
# variable_name     0
# X_lb              0
# Y_lb              0
# c                 9
# difference        0
# tsDiff            0
# X_el              0
# Y_el              0
# time_el           0
# time_lb           0
# dtype: int64

# %%
# Save cleaned data in the folder
df_xy.to_csv('./data/bothEyetrackesrData/timeseries_data.csv', index=False)

# %%
# df_xy = df_xy.loc[1631625944217:1631625948279]
df_xy.drop(columns="time_lb", inplace=True)
df_xy = df_xy.reset_index()
el = el.reset_index()
df_xy.time_el = df_xy.time_el.apply(lambda x: int('%.0f' % x))
# df_xy['t'] = pd.to_datetime(df_xy['t'], unit='ms')
df_xy.head()
# Out:
#          time_lb Block_Name  Block_Nr  exp_subject_id  rec_session_id  \
# 0  1636719510783    block_1         1          310735          341035
# 1  1636719510883    block_1         1          310735          341035
# 2  1636719510916    block_1         1          310735          341035
# 3  1636719510949    block_1         1          310735          341035
# 4  1636719510982    block_1         1          310735          341035
#
#    session_nr   Task_Name  Task_Nr          times  Trial_Id  Trial_Nr  \
# 0           1  large_grid        3  1636719510954        35         1
# 1           1  large_grid        3  1636719511004        35         1
# 2           1  large_grid        3  1636719511043        35         1
# 3           1  large_grid        3  1636719511071        35         1
# 4           1  large_grid        3  1636719511112        35         1
#
#   variable_name  X_lb  Y_lb         c  difference  tsDiff    X_el    Y_el  \
# 0          XYTC   876   596  0.269311       -71.0     NaN  954.70  562.05
# 1          XYTC   845   622  0.564112       -21.0   100.0  950.80  567.35
# 2          XYTC   836   633  0.567634       -27.0    33.0  958.50  569.30
# 3          XYTC   867   542  0.984854       -22.0    33.0  961.35  563.80
# 4          XYTC   886   553  0.985005       -30.0    33.0  955.45  563.15
#
#          time_el
# 0  1636719510783
# 1  1636719510883
# 2  1636719510915
# 3  1636719510949
# 4  1636719510981

# %%
df_xy = df_xy.loc[500:600]
df_xy
# Out:
#            time_lb Block_Name  Block_Nr  exp_subject_id  rec_session_id  \
# 500  1636719529965    block_1         1          310735          341035
# 501  1636719529999    block_1         1          310735          341035
# 502  1636719530035    block_1         1          310735          341035
# 503  1636719530101    block_1         1          310735          341035
# 504  1636719530134    block_1         1          310735          341035
# ..             ...        ...       ...             ...             ...
# 596  1636719547999    block_1         1          310735          341035
# 597  1636719548032    block_1         1          310735          341035
# 598  1636719548098    block_1         1          310735          341035
# 599  1636719548131    block_1         1          310735          341035
# 600  1636719548164    block_1         1          310735          341035
#
#      session_nr   Task_Name  Task_Nr          times  Trial_Id  Trial_Nr  \
# 500           1  large_grid        3  1636719530084        47         6
# 501           1  large_grid        3  1636719530131        47         6
# 502           1  large_grid        3  1636719530169        47         6
# 503           1  large_grid        3  1636719530219        47         6
# 504           1  large_grid        3  1636719530259        47         6
# ..          ...         ...      ...            ...       ...       ...
# 596           1  large_grid        3  1636719548111        13         7
# 597           1  large_grid        3  1636719548167        13         7
# 598           1  large_grid        3  1636719548227        13         7
# 599           1  large_grid        3  1636719548247        13         7
# 600           1  large_grid        3  1636719548296        13         7
#
#     variable_name  X_lb  Y_lb         c  difference  tsDiff    X_el    Y_el  \
# 500          XYTC   374   211  0.963932       -19.0    34.0  561.45  420.65
# 501          XYTC   330   282  0.941803       -32.0    34.0  561.60  420.60
# 502          XYTC   294   229  0.942376       -34.0    36.0  558.20  419.45
# 503          XYTC   319   307  1.000000       -18.0    66.0  561.30  424.80
# 504          XYTC   288   336  1.000000       -25.0    33.0  566.40  427.70
# ..            ...   ...   ...       ...         ...     ...     ...     ...
# 596          XYTC   697   107  1.000000       -12.0    34.0  953.10  216.75
# 597          XYTC   651    89  1.000000       -35.0    33.0  948.70  211.50
# 598          XYTC   579   119  1.000000       -29.0    66.0  947.25  204.80
# 599          XYTC   549    92  1.000000       -16.0    33.0  939.50  212.40
# 600          XYTC   568    73  0.767851       -32.0    33.0  944.20  214.45
#
#            time_el
# 500  1636719529965
# 501  1636719529999
# 502  1636719530035
# 503  1636719530101
# 504  1636719530133
# ..             ...
# 596  1636719547999
# 597  1636719548032
# 598  1636719548097
# 599  1636719548131
# 600  1636719548163
#
# [101 rows x 20 columns]

# %% [markdown]
# ## Calculation on the whole data set Labvanced and ET comp after downsampling

# %%
print('fragment of the data over time')
x1 = df_xy.time_lb
y1 = df_xy.Y_lb
    
x2 = df_xy.time_el
y2 = df_xy.Y_el

# plot
plt.legend()
plt.xlabel('Time in the miliseconds', fontsize=34)
plt.ylabel('Coordinates Y in pixels', fontsize=34)
plt.plot(x1,y1, c='b', label='Labvanced', linewidth=4, alpha=0.75)
plt.plot(x2,y2, c='r', label='EyeLink', linewidth=4, alpha=0.75)
# plt.legend(loc='upper left')
# plt.gcf().autofmt_xdate()
plt.gcf().set_size_inches((20, 11))
# ALWAYS FLIP y AXIS!!!!!!!!!!!!!!!
plt.gca().invert_yaxis()
plt.grid()
plt.show()

x1 = df_xy.time_lb
y1 = df_xy.X_lb
    
x2 = df_xy.time_el
y2 = df_xy.X_el

# plot
plt.legend()
plt.xlabel('Time in the miliseconds', fontsize=34)
plt.ylabel('Coordinates X in pixels', fontsize=34)
plt.plot(x1,y1, c='b', label='Labvanced', linewidth=4, alpha=0.75)
plt.plot(x2,y2, c='r', label='EyeLink', linewidth=4, alpha=0.75)
# plt.legend(loc='upper left')
# plt.gcf().autofmt_xdate()
plt.gcf().set_size_inches((20, 11))
# ALWAYS FLIP y AXIS!!!!!!!!!!!!!!!
plt.gca().invert_yaxis()
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
print('whole data')
x1 = lb.time_lb
y1 = lb.Y_lb
    
x2 = el.time_el
y2 = el.Y_el

# plot
plt.legend()
plt.xlabel('Time in the miliseconds', fontsize=20)
plt.ylabel('Coordinates Y in pixels', fontsize=20)
plt.plot(x1,y1, c='b', label='Labvanced', linewidth=4, alpha=0.75)
plt.plot(x2,y2, c='r', label='EyeLink', linewidth=4, alpha=0.75)
# plt.legend(loc='upper left')
# plt.gcf().autofmt_xdate()
plt.gcf().set_size_inches((20, 11))
# ALWAYS FLIP y AXIS!!!!!!!!!!!!!!!
plt.gca().invert_yaxis()
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.
