# %%
# Import many dataFrame for the Algorithm Comparison:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from matplotlib.lines import Line2D
from scipy import stats
import glob
import os
# pd.set_option('display.max_rows', 500)
from scipy.stats import gaussian_kde
from scipy.stats import sem
import seaborn as sns
from scipy.stats.mstats import winsorize

### Import our libraries
# some_file.py
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../data_preprocessing/')
import fixation_plots as plots
from utility import utilitiesCalc

# %%
lb_data = []
el_data = []
trial_data = []
for files in sorted(glob.glob("../data/lb_data/timeseries_data/*.csv"),key=os.path.getmtime):
    df_temp = pd.read_csv(files, index_col=False)
    lb_data.append(df_temp)
lb_gaze = pd.concat(lb_data, axis=0, ignore_index=True)
for files in sorted(glob.glob("../data/el_data/*.csv"),key=os.path.getmtime):
    df_temp = pd.read_csv(files, index_col=False)
    el_data.append(df_temp)
    
el_gaze = pd.concat(el_data, axis=0, ignore_index=True)
for files in sorted(glob.glob("../data/lb_data/trial_data/*.csv"),key=os.path.getmtime):
    df_temp = pd.read_csv(files, index_col=False)
    trial_data.append(df_temp)
all_trials = pd.concat(trial_data, axis=0, ignore_index=True)

# %%
lb_gaze = lb_gaze[lb_gaze['Task_Name'] == 'smooth_pursuit']
all_trials = all_trials[all_trials['Task_Name'] == 'smooth_pursuit']

# %%
lb_gaze
# Out:
#         Block_Nr Block_Name  Task_Nr       Task_Name  Trial_Nr  Trial_Id  \
# 1609         1.0    block_1        5  smooth_pursuit         1         5
# 1610         1.0    block_1        5  smooth_pursuit         1         5
# 1611         1.0    block_1        5  smooth_pursuit         1         5
# 1612         1.0    block_1        5  smooth_pursuit         1         5
# 1613         1.0    block_1        5  smooth_pursuit         1         5
# ...          ...        ...      ...             ...       ...       ...
# 181652       1.0    block_1        5  smooth_pursuit         6         6
# 181653       1.0    block_1        5  smooth_pursuit         6         6
# 181654       1.0    block_1        5  smooth_pursuit         6         6
# 181655       1.0    block_1        5  smooth_pursuit         6         6
# 181656       1.0    block_1        5  smooth_pursuit         6         6
#
#         Exp_Subject_Id  Rec_Session_Id  Session_Nr      timestamp       value  \
# ...

# %%
all_trials
# Out:
#       Rec_Session_Id  Block_Nr Block_Name  Task_Nr       Task_Name  Trial_Nr  \
# 19            409193         1    block_1        5  smooth_pursuit         1
# 20            409193         1    block_1        5  smooth_pursuit         2
# 21            409193         1    block_1        5  smooth_pursuit         3
# 22            409193         1    block_1        5  smooth_pursuit         4
# 23            409193         1    block_1        5  smooth_pursuit         5
# ...              ...       ...        ...      ...             ...       ...
# 1320          447540         1    block_1        5  smooth_pursuit         2
# 1321          447540         1    block_1        5  smooth_pursuit         3
# 1322          447540         1    block_1        5  smooth_pursuit         4
# 1323          447540         1    block_1        5  smooth_pursuit         5
# 1324          447540         1    block_1        5  smooth_pursuit         6
#
# ...

# %%
# # Create the column with the distance to target
# lb_fix = utilitiesCalc.calcEuclideanDistance(lb_fix, all_trials)
# # el_fix = utilitiesCalc.calcEuclideanDistance(el_fix, all_trials)
# lb_fix
# Out:
# Empty DataFrame
# Columns: [Block_Nr, Block_Name, Task_Nr, Task_Name, Trial_Nr, Trial_Id, Exp_Subject_Id, Rec_Session_Id, Session_Nr, timestamp, x, y, dur, ts, tf, disp, ��"Block_Nr", distance]
# Index: []

# %%
all_trials
# Out:
#       Rec_Session_Id  Block_Nr Block_Name  Task_Nr       Task_Name  Trial_Nr  \
# 19            409193         1    block_1        5  smooth_pursuit         1
# 20            409193         1    block_1        5  smooth_pursuit         2
# 21            409193         1    block_1        5  smooth_pursuit         3
# 22            409193         1    block_1        5  smooth_pursuit         4
# 23            409193         1    block_1        5  smooth_pursuit         5
# ...              ...       ...        ...      ...             ...       ...
# 1320          447540         1    block_1        5  smooth_pursuit         2
# 1321          447540         1    block_1        5  smooth_pursuit         3
# 1322          447540         1    block_1        5  smooth_pursuit         4
# 1323          447540         1    block_1        5  smooth_pursuit         5
# 1324          447540         1    block_1        5  smooth_pursuit         6
#
# ...
