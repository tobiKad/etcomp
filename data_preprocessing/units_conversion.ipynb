# %%
# Import many dataFrame for the Algorithm Comparison:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from matplotlib.lines import Line2D
from scipy import stats

import glob
import os

# internal imports
import fixation_plots as plots
from utility import utilitiesCalc

# %%
df_lb = pd.read_csv('../data/lb_data/fixations_data/p' + str(1) + '_fixations.csv')
df_lb_trial = pd.read_csv('../data/lb_data/lb_trial_pp/p' + str(1) + '_trial_pp.csv')

# %%
df_lb_trial
# Out:
#     Unnamed: 0  index  Rec_Session_Id  Block_Nr Block_Name  Task_Nr  \
# 0           28     28          401562         1    block_1        3
# 1           29     29          401562         1    block_1        3
# 2           30     30          401562         1    block_1        3
# 3           36     36          401562         1    block_1        3
# 4           37     37          401562         1    block_1        3
# 5           38     38          401562         1    block_1        3
# 6           39     39          401562         1    block_1        3
# 7           40     40          401562         1    block_1        3
# 8           42     42          401562         1    block_1        3
# 9           43     43          401562         1    block_1        3
# 10          46     46          401562         1    block_1        3
# 11          48     48          401562         1    block_1        3
# 12          50     50          401562         1    block_1        3
# ...

# %%
from math import atan2, degrees
h = 30 # Monitor height in cm
d = 60 # Distance between monitor and participant in cm
vertical = 900 # Vertical resolution of the monitor
size_in_px = 100 # The stimulus size in pixels
# Calculate the number of degrees that correspond to a single pixel. This will
# generally be a very small value, something like 0.03.
deg_per_px = degrees(atan2(.5*h, d)) / (.5*r)
print('%s degrees correspond to a single pixel' % deg_per_px)
# Out:
# 0.03119165215094773 degrees correspond to a single pixel
